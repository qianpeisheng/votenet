# %%
log_file = '/home/peisheng/votenet/log_scannet_b_1000_42_2024-05-16_00-47-50/log_train.txt'
with open(log_file, 'r') as f:
    lines = f.readlines()

# %%
#  print all lines that contain 'eval mAP:'
for line in lines:
    if 'eval mAP:' in line:
        print(line)
# Out:
# eval mAP: 0.008581
#
# eval mAP: 0.034500
#
# eval mAP: 0.044090
#
# eval mAP: 0.048827
#
# eval mAP: 0.050199
#
# eval mAP: 0.052970
#
# eval mAP: 0.060045
#
# eval mAP: 0.058967
#
# eval mAP: 0.065271
#
# eval mAP: 0.066137
#
# eval mAP: 0.066724
#
# eval mAP: 0.037553
#
# eval mAP: 0.029725
#
# eval mAP: 0.035197
#
# eval mAP: 0.029559
#
# eval mAP: 0.019724
#
# eval mAP: 0.014618
#
# eval mAP: 0.020682
#
# eval mAP: 0.018377
#
# eval mAP: 0.022680
#
# eval mAP: 0.020004
#
# eval mAP: 0.020023
#
# eval mAP: 0.024007
#
# eval mAP: 0.037700
#
# eval mAP: 0.042416
#
# eval mAP: 0.042310
#
# eval mAP: 0.054848
#
# eval mAP: 0.046368
#
# eval mAP: 0.053231
#
# eval mAP: 0.037256
#
# eval mAP: 0.059159
#
# eval mAP: 0.047838
#
# eval mAP: 0.048088
#
# eval mAP: 0.029072
#
# eval mAP: 0.050784
#
# eval mAP: 0.061486
#
# eval mAP: 0.057477
#
# eval mAP: 0.051413
#
# eval mAP: 0.065199
#
# eval mAP: 0.056295
#
# eval mAP: 0.044660
#
# eval mAP: 0.061504
#
# eval mAP: 0.050809
#
# ...
